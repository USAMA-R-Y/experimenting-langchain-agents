# %%
from crewai import Agent, Crew, Process, Task, LLM
from crewai_tools import SerperDevTool, ScrapeWebsiteTool, DirectoryReadTool, FileWriterTool, FileReadTool
from crewai.project import CrewBase, agent, crew, task
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
@CrewBase
class BlogCrew():
    """Blog Writing Crew"""
    agents_config = "config/agents.yml"
    tasks_config = "config/tasks.yml"

    @agent
    def researcher(self) -> Agent:
        return Agent(
            config=self.agents_config['research_agent'],
            tools=[SerperDevTool()],
            verbose=True,
        )

    @agent
    def writer(self) -> Agent:
        return Agent(
            config=self.agents_config['writer_agent'],
            verbose=True,
        )

    @task
    def research_task(self) -> Task:
        return Task(
            config=self.tasks_config['research_task'],
            agent=self.researcher()
        )

    @task
    def blog_task(self) -> Task:
        return Task(
            config=self.tasks_config['blog_task'],
            agent=self.writer()
        )

    @crew
    def crew(self) -> Crew:
        return Crew(
            agents=[self.researcher(), self.writer()],
            tasks=[self.research_task(), self.blog_task()],
        )

# %%
if __name__ == "__main__":
    blog_crew = BlogCrew()
    blog_crew.crew().kickoff(inputs={"topic": "The Future of Electrical Vehicles"})
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The Future of Electrical Vehicles as of year 2025.           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "search_query": "future of electric vehicles 2025 interesting facts projections"                             │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'future of electric vehicles 2025 interesting facts projections', 'type':           │
# │  'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Electric vehicles had a bumpy road in 2025 -  │
# │  NPR', 'link': 'https://www.npr.org/2025/12/29/nx-s1-5638592/electric-vehicles-2025', 'snippet': 'A suite of    │
# │  pro-EV federal policies have been reversed. Well-known vehicles have been discontinued. Sales plummeted.',     │
# │  'position': 1}, {'title': 'The 2025 EV Stories That Mattered Most - ZETA', 'link':                             │
# │  'https://www.zeta.org/insights/the-2025-ev-stories-that-mattered-most', 'snippet': 'According to data from     │
# │  Recurrent Auto, the number of new EVs for sale under $42,000 is projected to double from 8 to 17 next year.    │
# │  Affordability ...', 'position': 2}, {'title': 'Electric Vehicle Outlook | BloombergNEF', 'link':               │
# │  'https://about.bnef.com/insights/clean-transport/electric-vehicle-outlook/', 'snippet': "The Electric Vehicle  │
# │  Outlook is BNEF's annual flagship report looking at how electrification and other changes will impact road     │
# │  transport in the years ahead.", 'position': 3}, {'title': 'Driving into 2025: The Future of Electric Vehicles  │
# │  | J.P. Morgan', 'link': 'https://www.jpmorgan.com/insights/global-research/autos/electric-vehicles',           │
# │  'snippet': 'Mainly driven by China EV sales, global demand for lithium is expected to climb 20% by 2025,       │
# │  according to J.P. Morgan Research forecasts.', 'position': 4}, {'title': '2025 US Electric Vehicle Landscape:  │
# │  Market Growth and Regulatory ...', 'link':                                                                     │
# │  'https://www.morganlewis.com/pubs/2025/12/2025-us-electric-vehicle-landscape-market-growth-and-regulatory-pre  │
# │  ssures', 'snippet': 'EVs are expected to account for 9.1% of total vehicle sales in 2025, with projections     │
# │  indicating it could rise to 11.8% in 2026 and 26% by 2030.', 'position': 5}, {'title': 'The Global Electric    │
# │  Vehicle Market In 2025 - Virta', 'link': 'https://www.virta.global/global-electric-vehicle-market',            │
# │  'snippet': "It's predicted that 1,000 models will be available by ...                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 5 interesting and recent facts about The Future of Electrical Vehicles as of year 2025:               │
# │                                                                                                                 │
# │  *   The number of new electric vehicles (EVs) available for under $42,000 is projected to double from 8 to 17  │
# │  in 2025.                                                                                                       │
# │  *   Global demand for lithium, a key component in EV batteries, is expected to increase by 20% by 2025,        │
# │  primarily driven by EV sales in China.                                                                         │
# │  *   In the United States, EVs are anticipated to represent 9.1% of total vehicle sales in 2025.                │
# │  *   Globally, EVs comprised approximately 25% of all car sales in 2025, significantly outpacing the U.S.       │
# │  market where they accounted for 10%.                                                                           │
# │  *   The U.S. market experienced a "bumpy road" for EV sales in 2025, with a slower growth rate compared to     │
# │  previous years and some projections indicating sharply lower sales.                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The Future of Electrical Vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The future of electric vehicles (EVs) in 2025 presents a dynamic, evolving landscape. Globally, EVs captured   │
# │  a significant 25% of all car sales, demonstrating robust worldwide adoption. This surge is fueling a 20%       │
# │  increase in global lithium demand, primarily driven by strong sales in China. Consumers are also seeing more   │
# │  accessible options, with affordable EV models under $42,000 projected to double to 17. However, the U.S.       │
# │  market experienced a "bumpy road," with EVs comprising around 9.1% of total vehicle sales. Slower growth and   │
# │  some revised projections indicate regional challenges, contrasting with the strong global momentum and         │
# │  increasing accessibility of EVs.                                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
